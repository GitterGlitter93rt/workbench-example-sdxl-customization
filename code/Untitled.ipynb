# %%
# !pip install -q pynvml
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import time
import os
from pynvml import *

def clear():
    os.system('cls' if os.name == 'nt' else 'clear')

nvmlInit()

def get_gpu_info():
    device_count = nvmlDeviceGetCount()
    gpus = []
    
    for i in range(device_count):
        handle = nvmlDeviceGetHandleByIndex(i)
        
        name = nvmlDeviceGetName(handle)
        mem_info = nvmlDeviceGetMemoryInfo(handle)
        util = nvmlDeviceGetUtilizationRates(handle)
        temp = nvmlDeviceGetTemperature(handle, NVML_TEMPERATURE_GPU)
        
        gpus.append({
            "index": i,
            "name": name,
            "memory_used": mem_info.used / 1024**3,
            "memory_total": mem_info.total / 1024**3,
            "utilization": util.gpu,
            "temperature": temp
        })
    
    return gpus


while True:
    clear()
    gpus = get_gpu_info()
    
    print("🔥 GPU MONITOR (updates every 2s)\n")
    
    for gpu in gpus:
        print(f"GPU {gpu['index']}: {gpu['name']}")
        print(f"  Utilization: {gpu['utilization']}%")
        print(f"  VRAM: {gpu['memory_used']:.2f} / {gpu['memory_total']:.2f} GB")
        print(f"  Temp: {gpu['temperature']}°C")
        print("-" * 40)
    
    time.sleep(2)
# Out:
# 🔥 GPU MONITOR (updates every 2s)
#
# GPU 0: b'NVIDIA GeForce RTX 5080'
#   Utilization: 0%
#   VRAM: 0.36 / 15.92 GB
#   Temp: 31°C
# ----------------------------------------
# GPU 1: b'NVIDIA GeForce RTX 5080'
#   Utilization: 6%
#   VRAM: 1.91 / 15.92 GB
#   Temp: 48°C
# ----------------------------------------
# 🔥 GPU MONITOR (updates every 2s)
#
# GPU 0: b'NVIDIA GeForce RTX 5080'
#   Utilization: 0%
#   VRAM: 0.36 / 15.92 GB
#   Temp: 31°C
# ----------------------------------------
# GPU 1: b'NVIDIA GeForce RTX 5080'
#   Utilization: 1%
#   VRAM: 1.91 / 15.92 GB
#   Temp: 48°C
# ----------------------------------------
# 🔥 GPU MONITOR (updates every 2s)
#
# GPU 0: b'NVIDIA GeForce RTX 5080'
#   Utilization: 0%
#   VRAM: 0.36 / 15.92 GB
#   Temp: 31°C
# ----------------------------------------
# GPU 1: b'NVIDIA GeForce RTX 5080'
#   Utilization: 2%
#   VRAM: 1.91 / 15.92 GB
#   Temp: 48°C
# ----------------------------------------
# 🔥 GPU MONITOR (updates every 2s)
#
# ...
