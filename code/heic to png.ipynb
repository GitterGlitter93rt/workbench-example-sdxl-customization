# %%
pip install pillow pillow-heif

# %%
from PIL import Image, ImageOps
import pillow_heif
import os

# Enable HEIC support
pillow_heif.register_heif_opener()

input_folder = "../datasets/muren"
output_folder = "../datasets/muren_png"

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_filename = filename.rsplit(".", 1)[0] + ".png"
        output_path = os.path.join(output_folder, output_filename)

        try:
            image = Image.open(input_path)

            # Fix orientation (critical for iPhone HEIC)
            image = ImageOps.exif_transpose(image)

            # Convert to RGB (PNG supports it fine)
            image = image.convert("RGB")

            # Save as PNG (lossless)
            image.save(output_path, "PNG", compress_level=0)

            print(f"✅ Converted: {filename} → {output_filename}")

        except Exception as e:
            print(f"❌ Failed: {filename} → {e}")

print("\n🎉 Done converting HEIC → PNG")
# Out:
# ✅ Converted: IMG_7098.HEIC → IMG_7098.png
# ✅ Converted: IMG_7091.HEIC → IMG_7091.png
# ✅ Converted: IMG_7089.HEIC → IMG_7089.png
# ✅ Converted: IMG_7093.HEIC → IMG_7093.png
# ✅ Converted: IMG_7102.HEIC → IMG_7102.png
# ✅ Converted: IMG_7086.HEIC → IMG_7086.png
# ✅ Converted: IMG_7097.HEIC → IMG_7097.png
# ✅ Converted: IMG_7101.HEIC → IMG_7101.png
# ✅ Converted: IMG_7104.HEIC → IMG_7104.png
# ✅ Converted: IMG_7099.HEIC → IMG_7099.png
# ✅ Converted: IMG_7096.HEIC → IMG_7096.png
# ✅ Converted: IMG_7103.HEIC → IMG_7103.png
# ✅ Converted: IMG_7092.HEIC → IMG_7092.png
# ✅ Converted: IMG_7095.HEIC → IMG_7095.png
# ✅ Converted: IMG_7083.HEIC → IMG_7083.png
# ✅ Converted: IMG_7090.HEIC → IMG_7090.png
# ✅ Converted: IMG_7087.HEIC → IMG_7087.png
# ✅ Converted: IMG_7084.HEIC → IMG_7084.png
# ✅ Converted: IMG_7088.HEIC → IMG_7088.png
# ✅ Converted: IMG_7085.HEIC → IMG_7085.png
# ✅ Converted: IMG_7100.HEIC → IMG_7100.png
# ✅ Converted: IMG_7082.HEIC → IMG_7082.png
# ✅ Converted: IMG_7081.HEIC → IMG_7081.png
# ✅ Converted: IMG_7094.HEIC → IMG_7094.png
#
# 🎉 Done converting HEIC → PNG
